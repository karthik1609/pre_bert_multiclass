# %%
# %config Completer.use_jedi = False
import pandas as pd
import socmed

# %%
mdl = socmed.process('yulu_dataanalysis_bp.xlsx', 'Yulu_dataanalysis.xlsx', 'yulu.gplay.json')

# %%
mdl.model_data_prep(True, True)
# Out:
# (<fastai.data.core.DataLoaders at 0x7fd491889100>,
#  <fastai.data.core.DataLoaders at 0x7fd48c5c6a00>)

# %%
mdl.model_train(True, True)
# Out:
# Epoch 7: reducing lr to 0.0006870856145831222
# No improvement since epoch 5: early stopping
# No improvement since epoch 4: early stopping
# (<fastai.text.learner.LMLearner at 0x7fd474677e50>,
#  <fastai.text.learner.TextLearner at 0x7fd4746318b0>)
